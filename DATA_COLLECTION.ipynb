# %% [markdown]
# <a href="https://colab.research.google.com/github/KOUSHIKEYA-VADIKA/ML-Learning/blob/main/DATA_COLLECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Kaggle
#
# 2.UCI machine Learning repositary
#
# 3.Google Dataset Search

# %% [markdown]
# importing datasets through kaggle API

# %%
#installing the kaggle library

# !pip install kaggle

# %% [markdown]
# upload your kaggle.json file

# %%
#configuring the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Importing the Earthquake Dataset

# %%
#API to fetch the dataseyt from kaggle
#(here kaggle dataset command starting with ! mark)

# %%
#extracting the compressed dataset
from zipfile import ZipFile
dataset = '/content/archive.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
