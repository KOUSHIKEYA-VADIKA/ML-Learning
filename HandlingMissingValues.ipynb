# %% [markdown]
# <a href="https://colab.research.google.com/github/KOUSHIKEYA-VADIKA/ML-Learning/blob/main/HandlingMissingValues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Methods to handle missing values:
#
# 1.imputation
#
# 2.Dropping

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset to a pandas df
dataset=pd.read_csv('/content/synthetic_dataset[1].csv')

# %%
dataset.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %% [markdown]
# NaN represents not a number

# %%
dataset.shape
# Out:
# (4362, 5)

# %%
dataset.isnull().sum()
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64

# %% [markdown]
# Central Tendencies :
# 1.Mean
# 2.Median
# 3.Mode

# %%
#analyse the distribution of data in the price
fig,ax=plt.subplots(figsize=(10,5))
sns.distplot(dataset.Price)
# Out:
# /tmp/ipykernel_1195/238117325.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset.Price)
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# replace the missing values with mean as there are no extreme outliers.

# %%
dataset['Price'].fillna(dataset['Price'].mean())
# Out:
# 0       5548.00000
# 1       3045.00000
# 2       4004.00000
# 3       4808.00000
# 4       1817.00000
#            ...
# 4357    4436.00000
# 4358    6236.00000
# 4359    3283.00000
# 4360    2999.00000
# 4361    5016.97063
# Name: Price, Length: 4362, dtype: float64

# %% [markdown]
# to verify if it filled the missing values

# %%
dataset['Price'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# same with median and mode , only function changes in code

# %% [markdown]
# Dropping method .

# %%
price_dataset=pd.read_csv('/content/synthetic_dataset[1].csv')

# %%
price_dataset.shape
# Out:
# (4362, 5)

# %%
price_dataset.isnull().sum()
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64

# %%
#drop the missing values
price_dataset=price_dataset.dropna(how='any')

# %%
price_dataset.isnull().sum()
# Out:
# Category    0
# Price       0
# Rating      0
# Stock       0
# Discount    0
# dtype: int64

# %%
price_dataset.shape
# Out:
# (540, 5)
